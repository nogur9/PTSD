# %%
from catboost import CatBoostClassifier, CatBoostRegressor
from scipy import stats
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.metrics import precision_score, roc_auc_score, f1_score, recall_score, precision_recall_curve, auc, average_precision_score, precision_recall_fscore_support
from sklearn.preprocessing import StandardScaler
from fancyimpute import IterativeImputer
from sklearn.base import BaseEstimator, TransformerMixin

from sklearn.feature_selection import SelectFromModel, RFE
from sklearn.linear_model import LogisticRegression
from imblearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.formula.api import ols
from sklearn.model_selection import GridSearchCV
import xlsxwriter
from random import randint
random_state = 7656
from preprocessing import stds, stats, cv_preprocessing
from load_data import load_data
import os

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input
#from tensorflow.keras.layers import Conv2D, Activation
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
# Out:
# Using TensorFlow backend.
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
df_preprocessed['target_binary_intrusion'].sum()

# %%
target_feature

# %%
df_preprocessed, features, target_feature = load_data()

for i in range(len(target_feature)):
    print ('\n\n\n', target_feature[i], '\n-------------------')
    X, X_out, Y, y_out = train_test_split(df_preprocessed[features], df_preprocessed['target_binary_intrusion'],\
                                          test_size=0.25,\
                                          stratify=df_preprocessed['target_binary_intrusion'])



    for i in [random_state, random_state-195, random_state+344, random_state-347, random_state+89]:
        X_train, X_test, y_train, y_test = train_test_split(X, Y,  random_state=i, test_size=0.2, stratify=Y)
        cv = StratifiedKFold(6, random_state=i, shuffle=True)

        X_train, X_test = cv_preprocessing(X_train, X_test, i)

        pipe = Pipeline(steps=[
        ('rfe', RFE(ExtraTreesClassifier())),
        ('classifier', CatBoostClassifier(verbose=0, random_state=i))])

        grid_params = [{
        'rfe__n_features_to_select':[50, 100],
        'classifier__class_weights':[[3,1], [1, 15], [1, 30]],
        'classifier__l2_leaf_reg': [100, 30],# 50],
        'classifier__depth': [5],#, 9]
        }]
        clf = GridSearchCV(pipe, grid_params, cv=cv, scoring='roc_auc')
        clf.fit(X_train, y_train.values.astype(int))#, fit_params = {'classifier__early_stopping_rounds':15})
        print(f"i = {i}, roc_auc = {clf.best_score_}, params = {clf.best_params_}")
        y_pred_target = clf.best_estimator_.predict_proba(X_test)[:, 1]
        
        
        precision, recall, _ = precision_recall_curve(y_test.astype(int), y_pred_target)
        avs = average_precision_score(y_test.astype(int), y_pred_target)
        print(f"average_precision_score = {avs}")

        auc_score = auc(recall, precision)
        print(f"pr_auc = {auc_score}")
        plt.plot(recall, precision)
        plt.show()
#         print(f"holdout i = {i}, roc_auc = {roc_auc_score(y_test.astype(int), y_pred_target)}")
#         for i, j in zip(X_train.columns, clf.best_estimator_['rfe'].ranking_):
#             if j == 1:
#                 print(i)
#         print("\n\n\n")
# Out:
#  PCL_Strict3
# -------------------
# i = 7656, roc_auc = 0.7723207025532607, params = {'classifier__class_weights': [1, 15], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 100, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.4832430902125571
# pr_auc = 0.46457002460998315
# i = 7461, roc_auc = 0.7945262102238847, params = {'classifier__class_weights': [3, 1], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 30, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.38993950261726523
# pr_auc = 0.36374115632879356
# i = 8000, roc_auc = 0.7684989429175476, params = {'classifier__class_weights': [1, 15], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 30, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.48052965672891695
# pr_auc = 0.45354775081311494
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:693: RuntimeWarning: divide by zero encountered in true_divide
#   return self.resid / sigma / np.sqrt(1 - hii)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:773: RuntimeWarning: divide by zero encountered in true_divide
#   dfbetas /= np.sqrt(self.sigma2_not_obsi[:, None])
# i = 7309, roc_auc = 0.7846668835040927, params = {'classifier__class_weights': [1, 15], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 100, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.42154566829742435
# pr_auc = 0.396752894776752
# i = 7745, roc_auc = 0.7689190654306932, params = {'classifier__class_weights': [1, 15], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 30, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.5087433661475308
# pr_auc = 0.49483903719123146
#  target_tred
# -------------------
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:693: RuntimeWarning: divide by zero encountered in true_divide
#   return self.resid / sigma / np.sqrt(1 - hii)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:773: RuntimeWarning: divide by zero encountered in true_divide
#   dfbetas /= np.sqrt(self.sigma2_not_obsi[:, None])
# i = 7656, roc_auc = 0.7589242153195642, params = {'classifier__class_weights': [3, 1], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 30, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.3310551216397306
# pr_auc = 0.3015564100899048
# i = 7461, roc_auc = 0.758626063858622, params = {'classifier__class_weights': [1, 15], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 30, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.3433590422300873
# pr_auc = 0.3131208368674729
# i = 8000, roc_auc = 0.7304507507995881, params = {'classifier__class_weights': [1, 30], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 30, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.25765965675537694
# pr_auc = 0.24001327516737497
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:693: RuntimeWarning: invalid value encountered in true_divide
#   return self.resid / sigma / np.sqrt(1 - hii)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2007: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:773: RuntimeWarning: invalid value encountered in true_divide
#   dfbetas /= np.sqrt(self.sigma2_not_obsi[:, None])
# i = 7309, roc_auc = 0.7140320919390688, params = {'classifier__class_weights': [3, 1], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 100, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.4650438899593617
# pr_auc = 0.4514730648075309
# i = 7745, roc_auc = 0.7363460183227625, params = {'classifier__class_weights': [3, 1], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 100, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.47923155450728905
# pr_auc = 0.465247919434823
#  target_intrusion
# -------------------
# i = 7656, roc_auc = 0.6897598525505502, params = {'classifier__class_weights': [1, 15], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 100, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.4587056743530064
# pr_auc = 0.44069178096529976
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:693: RuntimeWarning: invalid value encountered in true_divide
#   return self.resid / sigma / np.sqrt(1 - hii)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2007: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:773: RuntimeWarning: invalid value encountered in true_divide
#   dfbetas /= np.sqrt(self.sigma2_not_obsi[:, None])
# i = 7461, roc_auc = 0.7580365371063046, params = {'classifier__class_weights': [1, 15], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 100, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.3109503209635718
# pr_auc = 0.28764145967979876
# i = 8000, roc_auc = 0.6781251694042392, params = {'classifier__class_weights': [3, 1], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 100, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.5015690397415624
# pr_auc = 0.48283165483868173
# i = 7309, roc_auc = 0.7087534558464791, params = {'classifier__class_weights': [3, 1], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 100, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.4480253046975132
# pr_auc = 0.4173413132011149
# i = 7745, roc_auc = 0.7072694747113352, params = {'classifier__class_weights': [1, 15], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 100, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.46398164847097023
# pr_auc = 0.43673222297464176
#  target_avoidance
# -------------------
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:693: RuntimeWarning: divide by zero encountered in true_divide
#   return self.resid / sigma / np.sqrt(1 - hii)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:773: RuntimeWarning: divide by zero encountered in true_divide
#   dfbetas /= np.sqrt(self.sigma2_not_obsi[:, None])
# i = 7656, roc_auc = 0.7312977719954464, params = {'classifier__class_weights': [3, 1], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 30, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.5615817567295049
# pr_auc = 0.5498293312296167
# i = 7461, roc_auc = 0.7398560741583998, params = {'classifier__class_weights': [3, 1], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 30, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.5596488930313386
# pr_auc = 0.5480546456620443
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:693: RuntimeWarning: invalid value encountered in true_divide
#   return self.resid / sigma / np.sqrt(1 - hii)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2007: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:773: RuntimeWarning: invalid value encountered in true_divide
#   dfbetas /= np.sqrt(self.sigma2_not_obsi[:, None])
# i = 8000, roc_auc = 0.7378842088144414, params = {'classifier__class_weights': [3, 1], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 100, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.5115776271667212
# pr_auc = 0.4804791816552809
# i = 7309, roc_auc = 0.7342115249091994, params = {'classifier__class_weights': [3, 1], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 100, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.4859389103234717
# pr_auc = 0.47195752273664054
# i = 7745, roc_auc = 0.7477774163820676, params = {'classifier__class_weights': [3, 1], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 100, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.45610825106638886
# pr_auc = 0.43807371761935
#  target_hyper
# -------------------
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:693: RuntimeWarning: invalid value encountered in true_divide
#   return self.resid / sigma / np.sqrt(1 - hii)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2007: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:773: RuntimeWarning: invalid value encountered in true_divide
#   dfbetas /= np.sqrt(self.sigma2_not_obsi[:, None])
# i = 7656, roc_auc = 0.7404320485715834, params = {'classifier__class_weights': [3, 1], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 30, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.46817893701508884
# pr_auc = 0.4569192142786526
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:693: RuntimeWarning: invalid value encountered in true_divide
#   return self.resid / sigma / np.sqrt(1 - hii)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2007: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:773: RuntimeWarning: invalid value encountered in true_divide
#   dfbetas /= np.sqrt(self.sigma2_not_obsi[:, None])
# i = 7461, roc_auc = 0.7690478126524637, params = {'classifier__class_weights': [3, 1], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 30, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.3337235037053195
# pr_auc = 0.30755248777933675
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:693: RuntimeWarning: invalid value encountered in true_divide
#   return self.resid / sigma / np.sqrt(1 - hii)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2007: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:773: RuntimeWarning: invalid value encountered in true_divide
#   dfbetas /= np.sqrt(self.sigma2_not_obsi[:, None])
# i = 8000, roc_auc = 0.680429067056974, params = {'classifier__class_weights': [3, 1], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 30, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.6275490301677249
# pr_auc = 0.5978771028325204
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:693: RuntimeWarning: invalid value encountered in true_divide
#   return self.resid / sigma / np.sqrt(1 - hii)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2007: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:773: RuntimeWarning: invalid value encountered in true_divide
#   dfbetas /= np.sqrt(self.sigma2_not_obsi[:, None])
# i = 7309, roc_auc = 0.7289328888166097, params = {'classifier__class_weights': [3, 1], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 100, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.550119163358354
# pr_auc = 0.5381000918249503
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\impute\_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:693: RuntimeWarning: invalid value encountered in true_divide
#   return self.resid / sigma / np.sqrt(1 - hii)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2007: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:773: RuntimeWarning: invalid value encountered in true_divide
#   dfbetas /= np.sqrt(self.sigma2_not_obsi[:, None])
# i = 7745, roc_auc = 0.6779828698433349, params = {'classifier__class_weights': [3, 1], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 30, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.5402943377296706
# pr_auc = 0.5081997969638992
#  phq3
# -------------------
# i = 7656, roc_auc = 0.7868284815959233, params = {'classifier__class_weights': [3, 1], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 100, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.39953939552670314
# pr_auc = 0.38655403788854875
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:693: RuntimeWarning: invalid value encountered in true_divide
#   return self.resid / sigma / np.sqrt(1 - hii)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2007: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:773: RuntimeWarning: invalid value encountered in true_divide
#   dfbetas /= np.sqrt(self.sigma2_not_obsi[:, None])
# i = 7461, roc_auc = 0.7256532227462461, params = {'classifier__class_weights': [3, 1], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 100, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.46664399842340204
# pr_auc = 0.4389567387712433
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:693: RuntimeWarning: divide by zero encountered in true_divide
#   return self.resid / sigma / np.sqrt(1 - hii)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:773: RuntimeWarning: divide by zero encountered in true_divide
#   dfbetas /= np.sqrt(self.sigma2_not_obsi[:, None])
# i = 8000, roc_auc = 0.7328630671653927, params = {'classifier__class_weights': [1, 30], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 100, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.5887081533934443
# pr_auc = 0.5789256330642807
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:693: RuntimeWarning: invalid value encountered in true_divide
#   return self.resid / sigma / np.sqrt(1 - hii)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2007: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:773: RuntimeWarning: invalid value encountered in true_divide
#   dfbetas /= np.sqrt(self.sigma2_not_obsi[:, None])
# i = 7309, roc_auc = 0.7659239984821381, params = {'classifier__class_weights': [1, 15], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 100, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.3166469168010704
# pr_auc = 0.2920057668214415
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:693: RuntimeWarning: invalid value encountered in true_divide
#   return self.resid / sigma / np.sqrt(1 - hii)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2007: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:773: RuntimeWarning: invalid value encountered in true_divide
#   dfbetas /= np.sqrt(self.sigma2_not_obsi[:, None])
# i = 7745, roc_auc = 0.7557732964709709, params = {'classifier__class_weights': [3, 1], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 100, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.3374117881852143
# pr_auc = 0.32154426495157395
#  target_binary_intrusion
# -------------------
# i = 7656, roc_auc = 0.7596628178023527, params = {'classifier__class_weights': [1, 30], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 30, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.4696455746498466
# pr_auc = 0.43814121708815246
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:693: RuntimeWarning: invalid value encountered in true_divide
#   return self.resid / sigma / np.sqrt(1 - hii)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2007: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:773: RuntimeWarning: invalid value encountered in true_divide
#   dfbetas /= np.sqrt(self.sigma2_not_obsi[:, None])
# i = 7461, roc_auc = 0.7389277389277389, params = {'classifier__class_weights': [3, 1], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 100, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.4569457403944834
# pr_auc = 0.42933984726441676
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:693: RuntimeWarning: divide by zero encountered in true_divide
#   return self.resid / sigma / np.sqrt(1 - hii)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:773: RuntimeWarning: divide by zero encountered in true_divide
#   dfbetas /= np.sqrt(self.sigma2_not_obsi[:, None])
# i = 8000, roc_auc = 0.7673198894129127, params = {'classifier__class_weights': [1, 15], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 100, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.4530752332642739
# pr_auc = 0.4345177356920864
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:693: RuntimeWarning: divide by zero encountered in true_divide
#   return self.resid / sigma / np.sqrt(1 - hii)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:773: RuntimeWarning: divide by zero encountered in true_divide
#   dfbetas /= np.sqrt(self.sigma2_not_obsi[:, None])
# i = 7309, roc_auc = 0.7619396107768202, params = {'classifier__class_weights': [1, 15], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 100, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.5722070448436369
# pr_auc = 0.5550941806201799
# i = 7745, roc_auc = 0.7506708407871199, params = {'classifier__class_weights': [3, 1], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 100, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.46918836628489763
# pr_auc = 0.45128695038565303
#  q6.1_INTRU_target
# -------------------
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:693: RuntimeWarning: divide by zero encountered in true_divide
#   return self.resid / sigma / np.sqrt(1 - hii)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:773: RuntimeWarning: divide by zero encountered in true_divide
#   dfbetas /= np.sqrt(self.sigma2_not_obsi[:, None])
# i = 7656, roc_auc = 0.7386431398059304, params = {'classifier__class_weights': [3, 1], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 100, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.38531117444289653
# pr_auc = 0.3587931807416025
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:693: RuntimeWarning: invalid value encountered in true_divide
#   return self.resid / sigma / np.sqrt(1 - hii)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2007: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:773: RuntimeWarning: invalid value encountered in true_divide
#   dfbetas /= np.sqrt(self.sigma2_not_obsi[:, None])
# i = 7461, roc_auc = 0.7286686182035019, params = {'classifier__class_weights': [3, 1], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 30, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.39679503223468116
# pr_auc = 0.3654749723655933
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:693: RuntimeWarning: divide by zero encountered in true_divide
#   return self.resid / sigma / np.sqrt(1 - hii)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:773: RuntimeWarning: divide by zero encountered in true_divide
#   dfbetas /= np.sqrt(self.sigma2_not_obsi[:, None])
# i = 8000, roc_auc = 0.7176505664877758, params = {'classifier__class_weights': [3, 1], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 100, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.4948931125632942
# pr_auc = 0.48085237201789927
# i = 7309, roc_auc = 0.7373353390795252, params = {'classifier__class_weights': [3, 1], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 30, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.3561728292958021
# pr_auc = 0.3298756087266141
# i = 7745, roc_auc = 0.716356318100504, params = {'classifier__class_weights': [3, 1], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 30, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.44989416554124745
# pr_auc = 0.4249696664266212
#  q6.2_DREAM_target
# -------------------
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:693: RuntimeWarning: divide by zero encountered in true_divide
#   return self.resid / sigma / np.sqrt(1 - hii)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:773: RuntimeWarning: divide by zero encountered in true_divide
#   dfbetas /= np.sqrt(self.sigma2_not_obsi[:, None])
# i = 7656, roc_auc = 0.7585244213151189, params = {'classifier__class_weights': [3, 1], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 100, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.5941923634903101
# pr_auc = 0.5879402830700995
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:693: RuntimeWarning: invalid value encountered in true_divide
#   return self.resid / sigma / np.sqrt(1 - hii)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2007: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:773: RuntimeWarning: invalid value encountered in true_divide
#   dfbetas /= np.sqrt(self.sigma2_not_obsi[:, None])
# i = 7461, roc_auc = 0.7167696644440831, params = {'classifier__class_weights': [3, 1], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 30, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.5502188471393399
# pr_auc = 0.537791805456202
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:693: RuntimeWarning: divide by zero encountered in true_divide
#   return self.resid / sigma / np.sqrt(1 - hii)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:773: RuntimeWarning: divide by zero encountered in true_divide
#   dfbetas /= np.sqrt(self.sigma2_not_obsi[:, None])
# i = 8000, roc_auc = 0.7436032959288773, params = {'classifier__class_weights': [3, 1], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 30, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.33894173572859954
# pr_auc = 0.31520876607511983
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:693: RuntimeWarning: invalid value encountered in true_divide
#   return self.resid / sigma / np.sqrt(1 - hii)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2007: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:773: RuntimeWarning: invalid value encountered in true_divide
#   dfbetas /= np.sqrt(self.sigma2_not_obsi[:, None])
# i = 7309, roc_auc = 0.74831273377785, params = {'classifier__class_weights': [3, 1], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 100, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.45135083636136114
# pr_auc = 0.4329321223417675
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:693: RuntimeWarning: invalid value encountered in true_divide
#   return self.resid / sigma / np.sqrt(1 - hii)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2007: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:773: RuntimeWarning: invalid value encountered in true_divide
#   dfbetas /= np.sqrt(self.sigma2_not_obsi[:, None])
# i = 7745, roc_auc = 0.7334458177481434, params = {'classifier__class_weights': [3, 1], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 30, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.5182970685931758
# pr_auc = 0.5080471466801435
#  q6.3_FLASH_target
# -------------------
# i = 7656, roc_auc = 0.7844635984170867, params = {'classifier__class_weights': [3, 1], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 100, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.4563218737118907
# pr_auc = 0.4477644250280086
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:693: RuntimeWarning: invalid value encountered in true_divide
#   return self.resid / sigma / np.sqrt(1 - hii)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2007: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:773: RuntimeWarning: invalid value encountered in true_divide
#   dfbetas /= np.sqrt(self.sigma2_not_obsi[:, None])
# i = 7461, roc_auc = 0.7522090312787987, params = {'classifier__class_weights': [3, 1], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 100, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.4911734079360179
# pr_auc = 0.4597175652341568
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:693: RuntimeWarning: invalid value encountered in true_divide
#   return self.resid / sigma / np.sqrt(1 - hii)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2007: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:773: RuntimeWarning: invalid value encountered in true_divide
#   dfbetas /= np.sqrt(self.sigma2_not_obsi[:, None])
# i = 8000, roc_auc = 0.7404320485715834, params = {'classifier__class_weights': [3, 1], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 30, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.5369894349267921
# pr_auc = 0.518711570148503
# i = 7309, roc_auc = 0.7832438878950506, params = {'classifier__class_weights': [3, 1], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 30, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.3703367392986503
# pr_auc = 0.33960988988724133
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:693: RuntimeWarning: divide by zero encountered in true_divide
#   return self.resid / sigma / np.sqrt(1 - hii)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:773: RuntimeWarning: divide by zero encountered in true_divide
#   dfbetas /= np.sqrt(self.sigma2_not_obsi[:, None])
# i = 7745, roc_auc = 0.7305794980213586, params = {'classifier__class_weights': [3, 1], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 100, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.5402988959573807
# pr_auc = 0.5222634204148444
#  q6.4_UPSET_target
# -------------------
# i = 7656, roc_auc = 0.7074117742722393, params = {'classifier__class_weights': [3, 1], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 30, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.5153881187915234
# pr_auc = 0.4851953066366216
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:693: RuntimeWarning: divide by zero encountered in true_divide
#   return self.resid / sigma / np.sqrt(1 - hii)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:773: RuntimeWarning: divide by zero encountered in true_divide
#   dfbetas /= np.sqrt(self.sigma2_not_obsi[:, None])
# i = 7461, roc_auc = 0.7377351330839703, params = {'classifier__class_weights': [1, 30], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 30, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.30128270528505907
# pr_auc = 0.27239734792227055
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:693: RuntimeWarning: divide by zero encountered in true_divide
#   return self.resid / sigma / np.sqrt(1 - hii)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:773: RuntimeWarning: divide by zero encountered in true_divide
#   dfbetas /= np.sqrt(self.sigma2_not_obsi[:, None])
# i = 8000, roc_auc = 0.7274624600205996, params = {'classifier__class_weights': [3, 1], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 30, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.3232575861219892
# pr_auc = 0.2941911264197918
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:693: RuntimeWarning: divide by zero encountered in true_divide
#   return self.resid / sigma / np.sqrt(1 - hii)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:773: RuntimeWarning: divide by zero encountered in true_divide
#   dfbetas /= np.sqrt(self.sigma2_not_obsi[:, None])
# i = 7309, roc_auc = 0.7325107063479156, params = {'classifier__class_weights': [3, 1], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 30, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.35398065968340287
# pr_auc = 0.3328291406622689
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:693: RuntimeWarning: divide by zero encountered in true_divide
#   return self.resid / sigma / np.sqrt(1 - hii)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:773: RuntimeWarning: divide by zero encountered in true_divide
#   dfbetas /= np.sqrt(self.sigma2_not_obsi[:, None])
# i = 7745, roc_auc = 0.6955670298693555, params = {'classifier__class_weights': [3, 1], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 100, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.4125307325465573
# pr_auc = 0.38783493581584944
#  q6.5_PHYS_target
# -------------------
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:693: RuntimeWarning: divide by zero encountered in true_divide
#   return self.resid / sigma / np.sqrt(1 - hii)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:773: RuntimeWarning: divide by zero encountered in true_divide
#   dfbetas /= np.sqrt(self.sigma2_not_obsi[:, None])
# i = 7656, roc_auc = 0.7742654632189515, params = {'classifier__class_weights': [3, 1], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 30, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.3365149993713824
# pr_auc = 0.306346400288905
# i = 7461, roc_auc = 0.7607944381200196, params = {'classifier__class_weights': [1, 30], 'classifier__depth': 5, 'classifier__l2_leaf_reg': 30, 'rfe__n_features_to_select': 50}
# average_precision_score = 0.41155426174211873
# pr_auc = 0.3807791620581393
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:693: RuntimeWarning: divide by zero encountered in true_divide
#   return self.resid / sigma / np.sqrt(1 - hii)
# C:\Users\nogag\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:773: RuntimeWarning: divide by zero encountered in true_divide
#   dfbetas /= np.sqrt(self.sigma2_not_obsi[:, None])

# %%
target_feature

# %%
df_preprocessed, features, target_feature = load_data()
df_preprocessed = df_preprocessed[~df_preprocessed['phq3'].isna()]
secondary_targets = ['PCL_Strict3',
 'target_avoidance',
 'target_hyper', 'phq3']

for i in range(len(target_feature)):
    print ('\n\n\n', target_feature[i], '\n-------------------')
    X, X_out, Y, y_out = train_test_split(df_preprocessed[features + secondary_targets], df_preprocessed['target_intrusion'] > 8,\
                                          test_size=0.25, random_state=random_state,\
                                          stratify=df_preprocessed['target_intrusion'] > 8)



    for i in [random_state, random_state-195, random_state+344, random_state-347, random_state+89]:
        
        x_train, x_test, y_train, y_test = train_test_split(X, Y,  random_state=i, test_size=0.2, stratify=Y)
        cv = StratifiedKFold(6, random_state=i, shuffle=True)
        
        train_targets = x_train[secondary_targets]
        test_targets = x_test[secondary_targets]
    
        x_train = x_train[features]
        x_test = x_test[features]
    
        x_train, x_test = cv_preprocessing(x_train, x_test, i)

        

        lr_intrusion = CatBoostClassifier(verbose=0, random_state=random_state, class_weights=[1,7])
        lr_avoidnce = CatBoostRegressor(verbose=0, random_state=random_state)
        lr_hyper = CatBoostRegressor(verbose=0, random_state=random_state)
        lr_phq = CatBoostRegressor(verbose=0, random_state=random_state)
        lr_ptsd = CatBoostClassifier(verbose=0, random_state=random_state, class_weights=[1,14])


        #lr_intrusion.fit(x_train, np.log(train_targets['target_intrusion'] + 1))
        lr_avoidnce.fit(x_train, np.log(train_targets['target_avoidance'] + 1))
        lr_hyper.fit(x_train, np.log(train_targets['target_hyper'] + 1))
        lr_phq.fit(x_train, np.log(train_targets['phq3']+1))
        
        lr_ptsd.fit(x_train, y_train.astype(int))
        lr_intrusion.fit(x_train, (train_targets['PCL_Strict3']).astype(int))


#         intrusion = lr_intrusion.predict_proba(x_test)[:,1]
#         avoidance = lr_avoidnce.predict_proba(x_test)[:,1]
#         hyper = lr_hyper.predict_proba(x_test)[:,1]
        
        #intrusion = lr_intrusion.predict(x_test)
        avoidance = lr_avoidnce.predict(x_test)
        hyper = lr_hyper.predict(x_test)
        phq = lr_hyper.predict(x_test)
        ptsd = lr_ptsd.predict_proba(x_test)[:, 1]
        intrusion = lr_intrusion.predict_proba(x_test)[:, 1]

    
        y_pred_target = (intrusion + ptsd*4)
        
        
        precision, recall, _ = precision_recall_curve(y_test.astype(int), y_pred_target)
        avs = average_precision_score(y_test.astype(int), y_pred_target)
        print(f"average_precision_score = {avs}")

        auc_score = auc(recall, precision)
        print(f"pr_auc = {auc_score}")
        plt.plot(recall, precision)
        plt.show()
        print(f"holdout i = {i}, roc_auc = {roc_auc_score(y_test.astype(int), y_pred_target)}")
#         for i, j in zip(X_train.columns, clf.best_estimator_['rfe'].ranking_):
#             if j == 1:
#                 print(i)
#         print("\n\n\n")

# %%
        visible = Input(shape=(102,))
        #x = Dense(30, activation='relu')(visible)
        #x = Dropout(0.5)(x)
        #x = Dropout(0.1)(x)

        x = Dense(10, activation='relu')(visible)
        #x = Dropout(0.5)(x)
        x = Dropout(0.1)(x)
        
        outputs = [Dense(1, activation='sigmoid')(x)]
        
        for i in targets_list:
            outputs.append(Dense(1, activation='sigmoid')(x))
    

        #outputs = [output1, output2, output3, output4, output5, output6,
         #          output7, output8, output9, output10, output11,
          #         output12, output13, output14, output15, output16,
           #        output17, output18, output19, output20, output21,
            #       output22, output23, output24, output25, output26]
        
        
        model = Model(inputs=visible, outputs=outputs)
        #callbacks = [EarlyStopping(monitor='val_loss', patience=5)]
        model.compile(loss=['binary_crossentropy']+['binary_crossentropy'] * len(targets_list),
              optimizer=Adam(), loss_weights = [1] + [1e-1] * len(targets_list))
        
        model.fit(X_train,y_trains , epochs = 250, verbose=0)
        # evaluate the model
        y_pred = (model.predict(X[features].iloc[test])[0] > lim).astype(int)

# %%
df_preprocessed, features, target_feature = load_data()
df_preprocessed = df_preprocessed[~df_preprocessed['phq3'].isna()]
secondary_targets = {
    'PCL_Strict3':1,
 'target_avoidance':5,
 'target_hyper':7,
    'phq3':13
}

for j in range(len(target_feature)):
    X, X_out, Y, y_out = train_test_split(df_preprocessed[features + list(secondary_targets.keys())], df_preprocessed['target_intrusion']>7,\
                                          test_size=0.15, random_state=random_state,\
                                          stratify=df_preprocessed['target_intrusion']>7)



    for i in [random_state, random_state-195, random_state+344, random_state-347, random_state+89]:
        x_train, x_test, y_train, y_test = train_test_split(X, Y,  random_state=i, test_size=0.2, stratify=Y)
        cv = StratifiedKFold(6, random_state=i, shuffle=True)
        y_train = [y_train]
        
        for k in secondary_targets.keys():
            y_train.append(x_train[k].apply(lambda x: int(x > secondary_targets[k])))
        
        #y_train[secondary_targets]=x_train[secondary_targets]
        x_train = x_train[features]
        x_test = x_test[features]
    
        x_train, x_test = cv_preprocessing(x_train, x_test, i)

        ss = StandardScaler()
        x_train = ss.fit_transform(x_train)
        x_test = ss.transform(x_test)
        visible = Input(shape=(x_train.shape[1],))
   

        x = Dense(10, activation='relu')(visible)
        x = Dropout(0.1)(x)
        
        outputs = [Dense(1, activation='sigmoid')(x)]
        
        
        for i in secondary_targets.keys():
            outputs.append(Dense(1, activation='sigmoid')(x))
        
        
        model = Model(inputs=visible, outputs=outputs)
        #callbacks = [EarlyStopping(monitor='val_loss', patience=5)]
        model.compile(loss=['binary_crossentropy']+['binary_crossentropy'] * len(secondary_targets.keys()),
              optimizer=Adam(), loss_weights = [1] + [1e-1] * len(secondary_targets.keys()))
        model.fit(x_train,y_train , epochs = 100, class_weight=[{0:1, 1:10}]+[{0:1,1:5}] * len(secondary_targets.keys()), verbose=0)
        # evaluate the model
        y_pred = model.predict(x_test)[0]



    
        for t in np.arange(0.1,1,0.1):
          #  print(t,'f1_score beta=0.5', precision_recall_fscore_support(y_test.astype(int), y_pred>t, beta=0.5))
           # print(t,'f1_score beta=1', precision_recall_fscore_support(y_test.astype(int), y_pred>t, beta=1))
            #print(t,'f1_score beta=2', precision_recall_fscore_support(y_test.astype(int), y_pred>t, beta=2))
            print(t,'f1_score', f1_score(y_test.astype(int), y_pred>t))

        
        precision, recall, _ = precision_recall_curve(y_test.astype(int), y_pred)
        avs = average_precision_score(y_test.astype(int), y_pred)
        print(f"average_precision_score = {avs}")

        auc_score = auc(recall, precision)
        print(f"pr_auc = {auc_score}")
        plt.plot(recall, precision)
        plt.show()
        print(f"holdout i = {i}, roc_auc = {roc_auc_score(y_test.astype(int), y_pred)}")
#         for i, j in zip(X_train.columns, clf.best_estimator_['rfe'].ranking_):
#             if j == 1:
#                 print(i)
#        print("\n\n\n")

# %%
df_preprocessed, features, target_feature = load_data()

# %%
target_feature

# %%
df_preprocessed, features, target_feature = load_data()
df_preprocessed = df_preprocessed[~df_preprocessed['phq3'].isna()]
secondary_targets = {
     'q6.1_INTRU_target':1,
 'q6.2_DREAM_target':1,
 'q6.3_FLASH_target':1,
 'q6.4_UPSET_target':1,
 'q6.5_PHYS_target':1,
 #   'PCL_Strict3':1,
# 'target_avoidance':5,
# 'target_hyper':7,
    #'phq3':13
}

# %%
target_feature

# %%
a = (df_preprocessed[secondary_targets.keys()] > 1).sum(axis=1) > 0

# %%
b = (df_preprocessed[secondary_targets.keys()] > 1)

# %%
(b.count()-b.sum())/b.sum()

# %%
(a.count()-a.sum())/a.sum()

# %%
df_preprocessed, features, target_feature = load_data()
df_preprocessed = df_preprocessed[~df_preprocessed['phq3'].isna()]
secondary_targets = {
     'q6.1_INTRU_target':1,
 'q6.2_DREAM_target':1,
 'q6.3_FLASH_target':1,
 'q6.4_UPSET_target':1,
 'q6.5_PHYS_target':1,
 #   'PCL_Strict3':1,
# 'target_avoidance':5,
# 'target_hyper':7,
 #   'phq3':13
}

for j in range(len(target_feature)):
    X, X_out, Y, y_out = train_test_split(df_preprocessed[features + list(secondary_targets.keys())], df_preprocessed['target_binary_intrusion'],\
                                          test_size=0.15, random_state=random_state,\
                                          stratify=df_preprocessed['target_binary_intrusion'])



    for i in [random_state, random_state-195, random_state+344, random_state-347, random_state+89]:
        x_train, x_test, y_train, y_test = train_test_split(X, Y,  random_state=i, test_size=0.2, stratify=Y)
        cv = StratifiedKFold(6, random_state=i, shuffle=True)
        y_train = [y_train]
        
        for k in secondary_targets.keys():
            y_train.append(x_train[k].apply(lambda x: int(x > secondary_targets[k])))
        
        #y_train[secondary_targets]=x_train[secondary_targets]
        x_train = x_train[features]
        x_test = x_test[features]
    
        x_train, x_test = cv_preprocessing(x_train, x_test, i)

        ss = StandardScaler()
        x_train = ss.fit_transform(x_train)
        x_test = ss.transform(x_test)
        visible = Input(shape=(x_train.shape[1],))
   

        x = Dense(10, activation='relu')(visible)
        x = Dropout(0.1)(x)
        
        outputs = [Dense(1, activation='sigmoid')(x)]
        
        
        for i in secondary_targets.keys():
            outputs.append(Dense(1, activation='sigmoid')(x))
        
        
        model = Model(inputs=visible, outputs=outputs)
        #callbacks = [EarlyStopping(monitor='val_loss', patience=5)]
        model.compile(loss=['binary_crossentropy']+['binary_crossentropy'] * len(secondary_targets.keys()),
              optimizer=Adam(), loss_weights = [1] + [1e-1] * len(secondary_targets.keys()))
        model.fit(x_train,y_train , epochs = 100, class_weight=[{0:1, 1:2}]+[{0:1,1:3}] * len(secondary_targets.keys()), verbose=0)
        # evaluate the model
        y_pred = model.predict(x_test)[0]



    
        for t in np.arange(0.1,1,0.1):
          #  print(t,'f1_score beta=0.5', precision_recall_fscore_support(y_test.astype(int), y_pred>t, beta=0.5))
           # print(t,'f1_score beta=1', precision_recall_fscore_support(y_test.astype(int), y_pred>t, beta=1))
            #print(t,'f1_score beta=2', precision_recall_fscore_support(y_test.astype(int), y_pred>t, beta=2))
            print(t,'f1_score', f1_score(y_test.astype(int), y_pred>t))

        
        precision, recall, _ = precision_recall_curve(y_test.astype(int), y_pred)
        avs = average_precision_score(y_test.astype(int), y_pred)
        print(f"average_precision_score = {avs}")

        auc_score = auc(recall, precision)
        print(f"pr_auc = {auc_score}")
        plt.plot(recall, precision)
        plt.show()
        print(f"holdout i = {i}, roc_auc = {roc_auc_score(y_test.astype(int), y_pred)}")
#         for i, j in zip(X_train.columns, clf.best_estimator_['rfe'].ranking_):
#             if j == 1:
#                 print(i)
#        print("\n\n\n")

# %%
df_preprocessed, features, target_feature = load_data()

# %%
df_preprocessed[features]
