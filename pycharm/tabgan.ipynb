# %%
import os
import glob

import numpy as np
import tensorflow as tf

from preprocessing import PCL_calculator, cv_preprocessing

import matplotlib.pyplot as plt
import numpy as np
import random
import tensorflow as tf
from tensorflow import keras
#from tensorflow.keras import layers
#import tensorflow_datasets as tfds


from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.metrics import precision_score, roc_auc_score, f1_score, recall_score, precision_recall_curve, auc, average_precision_score, precision_recall_fscore_support
#from xgboost import XGBClassifier
import pandas as pd
from load_data import load_data
import matplotlib.pyplot as plt
from tabgan.sampler import OriginalGenerator, GANGenerator
from catboost import CatBoostClassifier
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.metrics import precision_score, roc_auc_score, auc, average_precision_score, precision_recall_curve

# %%
def print_results(y_true, y_pred, name = ''):
    
    precision, recall, _ = precision_recall_curve(y_true, y_pred)
    avs = average_precision_score(y_true, y_pred)
    auc_score = auc(recall, precision)
    
    print ('/n/n', name)

    plt.plot(recall, precision)
    plt.title("recall precision curve")

    plt.show()
    
    plt.hist(y_pred)
    plt.title("prediction histogram")
    plt.show()

    print(f"pr_auc = {auc_score}")

    print(f"average_precision_score = {avs}")

    print(f"holdout i = , roc_auc = {roc_auc_score(y_true, y_pred)}")

# %%
    
df_preprocessed, features, target_feature = load_data()
df_preprocessed = df_preprocessed.dropna(subset = ['target_binary_intrusion'], how='any')
    
    
    
X, X_out, Y, y_out = train_test_split(df_preprocessed[features], df_preprocessed['target_binary_intrusion'],\
                                          test_size=0.15,\
                                          stratify=df_preprocessed['target_binary_intrusion'])


cv = StratifiedKFold(5)

# %%
for train, test in cv.split(X, Y):
    x_train, y_train = X.iloc[train], Y.iloc[train]
    x_test, y_test = X.iloc[test], Y.iloc[test]

    x_train, x_test = cv_preprocessing(x_train, x_test)
    x_train = pd.DataFrame(x_train)
    x_test = pd.DataFrame(x_test)
    y_train = pd.DataFrame(y_train)
    
    
    
     #generate data
    new_train1, new_target1 = OriginalGenerator().generate_data_pipe(x_train, y_train, x_test, )
    new_train2, new_target2 = GANGenerator().generate_data_pipe(x_train, y_train, x_test, )

    # example with all params defined
    new_train3, new_target3 = GANGenerator(gen_x_times=1.1, cat_cols=None, bot_filter_quantile=0.001,
                                       top_filter_quantile=0.999,
                                       is_post_process=True,
                                       adversaial_model_params={
                                           "metrics": "AUC", "max_depth": 2,
                                           "max_bin": 100, "n_estimators": 500,
                                           "learning_rate": 0.02, "random_state": 42,
                                       }, pregeneration_frac=2,
                                       epochs=500).generate_data_pipe(train, target,
                                                                      test, deep_copy=True,
                                                                      only_adversarial=False,
                                                                      use_adversarial=True)
    # create the model
    input_shape = x_support.shape[1]  # first shape is batch_size

    #%% Training

    model = CatBoostClassifier()
    model.fit(x =new_train3, y = new_target3, class_weights={0:1,1:5})
    y_pred = model.predict_proba(x_test)[:,1]
    print_results(y_test, y_pred)
        
   # y_pred = test_time_augmentation(model, x_test, n)
    #print_results(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-96ff289b106b> in <module>
#      11
#      12      #generate data
# ---> 13     new_train1, new_target1 = OriginalGenerator().generate_data_pipe(x_train, y_train, x_test, )
#      14     new_train2, new_target2 = GANGenerator().generate_data_pipe(x_train, y_train, x_test, )
#      15
#
# ~\Anaconda3\lib\site-packages\tabgan\abc_sampler.py in generate_data_pipe(self, train_df, target, test_df, deep_copy, only_adversarial, use_adversarial)
#      48             new_train, new_target = generator.postprocess_data(new_train, new_target, test_df)
#      49             if use_adversarial:
# ---> 50                 new_train, new_target = generator.adversarial_filtering(new_train, new_target, test_df)
#      51             gc.collect()
#      52             return new_train, new_target
#
# ~\Anaconda3\lib\site-packages\tabgan\sampler.py in adversarial_filtering(self, train_df, target, test_df)
#     128         ad_model = AdversarialModel(cat_cols=self.cat_cols,
#     129                                     model_params=self.adversarial_model_params)
# --> 130         self._validate_data(train_df, target, test_df)
#     131         train_df[self.TEMP_TARGET] = target
#     132         ad_model.adversarial_test(test_df, train_df.drop(self.TEMP_TARGET, axis=1))
#
# ~\Anaconda3\lib\site-packages\tabgan\sampler.py in _validate_data(self, train_df, target, test_df)
#     142     def _validate_data(self, train_df, target, test_df):
#     143         if train_df.shape[0] < 10 or test_df.shape[0] < 10:
# --> 144             raise ValueError("Shape of train is {} and test is {} should at least 10! "
#     145                              "Consider disabling adversarial training".
#     146                              format(train_df.shape[0], test_df.shape[0]))
#
# ValueError: Shape of train is 0 and test is 92 should at least 10! Consider disabling adversarial training
